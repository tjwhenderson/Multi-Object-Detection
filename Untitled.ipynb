# %%
import os

def load_xml_from_folder(folder):
    xmlfile = []
    for filename in os.listdir(folder):
        if "2012" not in filename: 
            continue
        else:
            xmlfile.append(filename)
    return xmlfile
        
filelist = load_xml_from_folder("/datasets/ee285f-public/PascalVOC2012/Annotations/")

# %%
print(filelist)
# Out:
# ['2012_000229.xml', '2012_001469.xml', '2012_000648.xml', '2012_000699.xml', '2012_004020.xml', '2012_003838.xml', '2012_004178.xml', '2012_001181.xml', '2012_002094.xml', '2012_003173.xml', '2012_001247.xml', '2012_003960.xml', '2012_002856.xml', '2012_002424.xml', '2012_003264.xml', '2012_000371.xml', '2012_001296.xml', '2012_001531.xml', '2012_001943.xml', '2012_003605.xml', '2012_002045.xml', '2012_001150.xml', '2012_002972.xml', '2012_003340.xml', '2012_000255.xml', '2012_000980.xml', '2012_001415.xml', '2012_003721.xml', '2012_001074.xml', '2012_000142.xml', '2012_001702.xml', '2012_002617.xml', '2012_001363.xml', '2012_000523.xml', '2012_003436.xml', '2012_002276.xml', '2012_004104.xml', '2012_003347.xml', '2012_002166.xml', '2012_003081.xml', '2012_000633.xml', '2012_001073.xml', '2012_000145.xml', '2012_003050.xml', '2012_002610.xml', '2012_000524.xml', '2012_000956.xml', '2012_002271.xml', '2012_003843.xml', '2012_003431.xml', '2012_003108.xml', '2012_004103.xml', '2012_003
# ...

# %%
import pandas as pd
import xml.etree.ElementTree as ET

for file in filelist:
    path = os.path.join("/datasets/ee285f-public/PascalVOC2012/Annotations/", file)
    xml = path
    tree = ET.parse(xml)
    root = tree.getroot()
    print(root)
    
    name = []
    for obj in root.iter('object'):
        
    
    name.append(root[2][0])
    xmin[file] = root[3][0]
    xmax[file] = root[3][1].txt
    ymin[file] = root[3][2].txt
    ymax[file] = root[3][3].txt
# Out:
# <Element 'annotation' at 0x7f2801bdedb8>
# name person
# actions
#
# bndbox
#
# difficult 0
# pose Unspecified
# point
#
# depth 3
# height 333
# width 500
# annotation PASCAL VOC2012
# database The VOC2012 Database
# image flickr
# {}
# IndexErrorTraceback (most recent call last)
# <ipython-input-55-51e7ed69ce96> in <module>()
#      17
#      18     name.append(root[2][0])
# ---> 19     xmin[file] = root[3][0]
#      20     xmax[file] = root[3][1].txt
#      21     ymin[file] = root[3][2].txt
#
# IndexError: child index out of range
